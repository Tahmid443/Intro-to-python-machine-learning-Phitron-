# %% [markdown]
# ## Conditional statements

# %%
raining  = True
muddy = True
if raining:
    if muddy:
        print("You need umbrella and boot")
    else:
        print("You need umbrella")
else:
    print("You dont need umbrella")
# Out:
# You need umbrella and boot

# %%
taka = 400
#if greater than 500 than go for tour
#if greater than 400 than order food in home
#if greater than 300 than go to restraunt
#otherwise savings
if taka>500:
    print("Tour")
elif taka>400:
    print("Order food")
elif taka>300:
    print("Go to restraunt")
else:
    print("Save your money")
# Out:
# Go to restraunt

# %%
money = 300
raining = True
if money>500 and raining:
    print("taka ase but bahire bristy")
elif money>500 and raining == False:
    print("Taka ase khaite jamu")
elif money < 500 and raining == True:
    print("Bristy barse... taka o nai")
else:
    print("taka o nai bristy o nai...gorib")
# Out:
# Bristy barse... taka o nai
