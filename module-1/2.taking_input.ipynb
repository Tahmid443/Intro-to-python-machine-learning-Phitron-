# %%
name  = input("What is your name?")
print(name)
# Out:
# Tahmid

# %%
#python take string as input everytime by default
age = input("Enter your age:")
print(age, type(age))
# Out:
# 50 <class 'str'>

# %%
age = input("Enter your age:")
age = int(age) #converting age variable datatype into integer
print(age, type(age))
# Out:
# 30 <class 'int'>

# %%
height = input("Enter your height:")
height = float(height) #converting age variable datatype into float
print(height, type(height))
# Out:
# 32.5 <class 'float'>
