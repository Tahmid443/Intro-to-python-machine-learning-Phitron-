# %% [markdown]
# ## Variable and Datatype

# %%
'''
1.Only English letter and only underscore in special charachter
2.Cant start with digit
'''
# Out:
# '\n1.Only English letter and only underscore in special charachter\n2.Cant start with digit\n'

# %%
phone_number = 534234325
print(phone_number)
# Out:
# 534234325

# %%
name = "Phitron"
print(name)
# Out:
# Phitron

# %%
age = 21 #int
height = 5.6 #float
name  = "Tahmid" #string
is_passed = True #bool

age = 31 # age value is updated

#type of a variable
print(type(age), type(height), type(name), type(is_passed))

age = 20.5
print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# <class 'float'>
